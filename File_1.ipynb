# %%
import os
import pandas as pd
import textract

# %% [markdown]
# # List of files

# %%
os.listdir('C:\\Users\\admin\\Desktop\\Project_Docs\\Resumes')
# Out:
# ['Internship',
#  'Peoplesoft resumes',
#  'React JS Developer',
#  'SQL Developer Lightning insight',
#  'workday resumes']

# %% [markdown]
# # Extract the Text

# %%
file_path1 = []
category1  = []
directory1 = 'C:\\Users\\admin\\Desktop\\Project_Docs\\Resumes\\Peoplesoft resumes'
for i in os.listdir(directory1):
    if i.endswith('.docx'):
        os.path.join(directory1, i)
        file_path1.append((textract.process(os.path.join(directory1, i))).decode('utf-8'))
        category1.append('Peoplesoft resumes')

# %%
data1 = pd.DataFrame(data = file_path1 , columns = ['Raw_Details'])
data1['Category1'] = category1
data1
# Out:
#                                          Raw_Details           Category1
# 0  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...  Peoplesoft resumes
# 1  Classification: Internal\n\nClassification: In...  Peoplesoft resumes
# 2  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...  Peoplesoft resumes
# 3  PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...  Peoplesoft resumes
# 4  PeopleSoft Administration\n\n \n\nVivekanand S...  Peoplesoft resumes
# 5  Hari Narayana \t\t              \n\n\t\n\n\n\n...  Peoplesoft resumes
# 6  Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...  Peoplesoft resumes
# 7  Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...  Peoplesoft resumes
# 8  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...  Peoplesoft resumes
# 9  C O N T A C T :\n\n\n\nAddress: Manyata Tech P...  Peoplesoft resumes

# %%
file_path2 = []
category2  = []
directory2 = 'C:\\Users\\admin\\Desktop\\Project_Docs\\Resumes\\React JS Developer'
for i in os.listdir(directory2):
    if i.endswith('.docx'):
        os.path.join(directory2, i) 
        file_path2.append((textract.process(os.path.join(directory2, i))).decode('utf-8'))
        category2.append('React JS Developer')

# %%
data2 = pd.DataFrame(data = file_path2 , columns = ['Raw_Details'])
data2['Category2'] = category2
data2
# Out:
#                                           Raw_Details           Category2
# 0   Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...  React JS Developer
# 1   HARIPRIYA BATTINA \n\nExperience as UI Develop...  React JS Developer
# 2   KAMALAKAR REDDY. A \n\nLinked In: https://www....  React JS Developer
# 3   Naveen Sadhu\n\n\n\n\n\nTitle: software develo...  React JS Developer
# 4   PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...  React JS Developer
# 5   SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...  React JS Developer
# 6   Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...  React JS Developer
# 7   Ui-Developer/ React JS Developer \n\nNAME: KRI...  React JS Developer
# 8   Ui-Developer/ React JS Developer \n\nNAME: KRI...  React JS Developer
# 9   Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...  React JS Developer
# 10  Venkatalakshmi Pedireddy\n\nSoftware Developer...  React JS Developer
# 11  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...  React JS Developer
# ...

# %%
file_path3 = []
category3  = []
directory3 = 'C:\\Users\\admin\\Desktop\\Project_Docs\\Resumes\\SQL Developer Lightning insight'
for i in os.listdir(directory3):
    if i.endswith('.docx'):
        os.path.join(directory3, i)
        file_path3.append((textract.process(os.path.join(directory3, i))).decode('utf-8'))
        category3.append('SQL Developer Lightning insight')

# %%
data3 = pd.DataFrame(data = file_path3 , columns = ['Raw_Details'])
data3['Category3'] = category3
data3
# Out:
#                                           Raw_Details  \
# 0   ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...
# 1   Aradhana Tripathi\n\n\n\nCurrent Location: Gac...
# 2   BUDDHA VAMSI                                  ...
# 3   KAMBALLA PRADEEP                              ...
# 4   Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...
# 5   SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...
# 6   SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...
# 7   RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...
# 8   resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...
# 9   Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...
# 10  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...
#
#                           Category3
# 0   SQL Developer Lightning insight
# 1   SQL Developer Lightning insight
# 2   SQL Developer Lightning insight
# 3   SQL Developer Lightning insight
# 4   SQL Developer Lightning insight
# 5   SQL Developer Lightning insight
# 6   SQL Developer Lightning insight
# ...

# %%
file_path4 = []
category4  = []
directory4 = 'C:\\Users\\admin\\Desktop\\Project_Docs\\Resumes\\workday resumes'
for i in os.listdir(directory4):
    if i.endswith('.docx'):
        os.path.join(directory4, i)
        file_path4.append((textract.process(os.path.join(directory4, i))).decode('utf-8'))
        category4.append('workday resumes')

# %%
data4 = pd.DataFrame(data = file_path4 , columns = ['Raw_Details'])
data4['Category4'] = category4
data4
# Out:
#                                           Raw_Details        Category4
# 0   Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...  workday resumes
# 1   Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...  workday resumes
# 2   G Himaja\n\n                                  ...  workday resumes
# 3   JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...  workday resumes
# 4   Mooraboyina Guravaiah\n\nWorkday Integration S...  workday resumes
# 5   VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...  workday resumes
# 6   Workday HCM  Techno functional Consultant     ...  workday resumes
# 7   Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...  workday resumes
# 8   Srikanth (WORKDAY hCM Consultant)\t           ...  workday resumes
# 9   WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...  workday resumes
# 10  Vinay kumar .v\nWorkday Functional Consultant\...  workday resumes

# %%
file_path5 = []
category5  = []
directory5 = 'C:\\Users\\admin\\Desktop\\Project_Docs\\Resumes\\Internship'
for i in os.listdir(directory5):
    if i.endswith('.docx'):
        os.path.join(directory5, i)
        file_path5.append((textract.process(os.path.join(directory5, i))).decode('utf-8'))
        category5.append('Internship')

# %%
data5 = pd.DataFrame(data = file_path5 , columns = ['Raw_Details'])
data5['Category5'] = category5
data5
# Out:
#                                          Raw_Details   Category5
# 0  Name: Ravali P \n\n\n\n                       ...  Internship
# 1  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...  Internship

# %% [markdown]
# # Append all the resumes Category

# %%
resume_data = data1.append([data2, data3, data4, data5], ignore_index = True)
resume_data
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5492\1118408777.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   resume_data = data1.append([data2, data3, data4, data5], ignore_index = True)
#                                           Raw_Details           Category1  \
# 0   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...  Peoplesoft resumes
# 1   Classification: Internal\n\nClassification: In...  Peoplesoft resumes
# 2   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...  Peoplesoft resumes
# 3   PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...  Peoplesoft resumes
# 4   PeopleSoft Administration\n\n \n\nVivekanand S...  Peoplesoft resumes
# 5   Hari Narayana \t\t              \n\n\t\n\n\n\n...  Peoplesoft resumes
# 6   Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...  Peoplesoft resumes
# 7   Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...  Peoplesoft resumes
# ...

# %%
resume_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Raw_Details  52 non-null     object
#  1   Category1    10 non-null     object
#  2   Category2    18 non-null     object
#  3   Category3    11 non-null     object
#  4   Category4    11 non-null     object
#  5   Category5    2 non-null      object
# dtypes: object(6)
# memory usage: 2.6+ KB

# %%
resume_data['Category'] = category1 + category2 + category3 + category4 + category5
resume_data
# Out:
#                                           Raw_Details           Category1  \
# 0   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...  Peoplesoft resumes
# 1   Classification: Internal\n\nClassification: In...  Peoplesoft resumes
# 2   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...  Peoplesoft resumes
# 3   PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...  Peoplesoft resumes
# 4   PeopleSoft Administration\n\n \n\nVivekanand S...  Peoplesoft resumes
# 5   Hari Narayana \t\t              \n\n\t\n\n\n\n...  Peoplesoft resumes
# 6   Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...  Peoplesoft resumes
# 7   Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...  Peoplesoft resumes
# 8   Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...  Peoplesoft resumes
# 9   C O N T A C T :\n\n\n\nAddress: Manyata Tech P...  Peoplesoft resumes
# 10  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...                 NaN
# 11  HARIPRIYA BATTINA \n\nExperience as UI Develop...                 NaN
# ...

# %%
resume_data.drop(['Category1', 'Category2', 'Category3', 'Category4', 'Category5'], axis = 1, inplace = True)
resume_data = resume_data[["Category", "Raw_Details"]]

# %%
resume_data
# Out:
#                            Category  \
# 0                Peoplesoft resumes
# 1                Peoplesoft resumes
# 2                Peoplesoft resumes
# 3                Peoplesoft resumes
# 4                Peoplesoft resumes
# 5                Peoplesoft resumes
# 6                Peoplesoft resumes
# 7                Peoplesoft resumes
# 8                Peoplesoft resumes
# 9                Peoplesoft resumes
# 10               React JS Developer
# 11               React JS Developer
# 12               React JS Developer
# 13               React JS Developer
# 14               React JS Developer
# 15               React JS Developer
# 16               React JS Developer
# 17               React JS Developer
# 18               React JS Developer
# 19               React JS Developer
# 20               React JS Developer
# 21               React JS Developer
# 22               React JS Developer
# 23               React JS Developer
# 24               React JS Developer
# ...

# %% [markdown]
# # Create the Data Frame

# %%
resume_data.to_csv('Raw_Resume.csv', index=False)

# %%
resume_data = pd.read_csv("Raw_Resume.csv")
resume_data
# Out:
#                            Category  \
# 0                Peoplesoft resumes
# 1                Peoplesoft resumes
# 2                Peoplesoft resumes
# 3                Peoplesoft resumes
# 4                Peoplesoft resumes
# 5                Peoplesoft resumes
# 6                Peoplesoft resumes
# 7                Peoplesoft resumes
# 8                Peoplesoft resumes
# 9                Peoplesoft resumes
# 10               React JS Developer
# 11               React JS Developer
# 12               React JS Developer
# 13               React JS Developer
# 14               React JS Developer
# 15               React JS Developer
# 16               React JS Developer
# 17               React JS Developer
# 18               React JS Developer
# 19               React JS Developer
# 20               React JS Developer
# 21               React JS Developer
# 22               React JS Developer
# 23               React JS Developer
# 24               React JS Developer
# ...

# %% [markdown]
# # Understand the Dataset

# %%
resume_data[resume_data.Category == 'Peoplesoft resumes']
# Out:
#              Category                                        Raw_Details
# 0  Peoplesoft resumes  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 1  Peoplesoft resumes  Classification: Internal\n\nClassification: In...
# 2  Peoplesoft resumes  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...
# 3  Peoplesoft resumes  PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...
# 4  Peoplesoft resumes  PeopleSoft Administration\n\n \n\nVivekanand S...
# 5  Peoplesoft resumes  Hari Narayana \t\t              \n\n\t\n\n\n\n...
# 6  Peoplesoft resumes  Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...
# 7  Peoplesoft resumes  Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...
# 8  Peoplesoft resumes  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...
# 9  Peoplesoft resumes  C O N T A C T :\n\n\n\nAddress: Manyata Tech P...

# %%
resume_data[resume_data.Category == 'React JS Developer']
# Out:
#               Category                                        Raw_Details
# 10  React JS Developer  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...
# 11  React JS Developer  HARIPRIYA BATTINA \n\nExperience as UI Develop...
# 12  React JS Developer  KAMALAKAR REDDY. A \n\nLinked In: https://www....
# 13  React JS Developer  Naveen Sadhu\n\n\n\n\n\nTitle: software develo...
# 14  React JS Developer  PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...
# 15  React JS Developer  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...
# 16  React JS Developer  Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...
# 17  React JS Developer  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 18  React JS Developer  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 19  React JS Developer  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...
# 20  React JS Developer  Venkatalakshmi Pedireddy\n\nSoftware Developer...
# 21  React JS Developer  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...
# ...

# %%
resume_data[resume_data.Category == 'SQL Developer Lightning insight']
# Out:
#                            Category  \
# 28  SQL Developer Lightning insight
# 29  SQL Developer Lightning insight
# 30  SQL Developer Lightning insight
# 31  SQL Developer Lightning insight
# 32  SQL Developer Lightning insight
# 33  SQL Developer Lightning insight
# 34  SQL Developer Lightning insight
# 35  SQL Developer Lightning insight
# 36  SQL Developer Lightning insight
# 37  SQL Developer Lightning insight
# 38  SQL Developer Lightning insight
#
#                                           Raw_Details
# 28  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...
# 29  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...
# 30  BUDDHA VAMSI                                  ...
# 31  KAMBALLA PRADEEP                              ...
# 32  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...
# 33  SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...
# 34  SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...
# 35  RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...
# ...

# %%
resume_data[resume_data.Category == 'workday resumes']
# Out:
#            Category                                        Raw_Details
# 39  workday resumes  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...
# 40  workday resumes  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...
# 41  workday resumes  G Himaja\n\n                                  ...
# 42  workday resumes  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...
# 43  workday resumes  Mooraboyina Guravaiah\n\nWorkday Integration S...
# 44  workday resumes  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...
# 45  workday resumes  Workday HCM  Techno functional Consultant     ...
# 46  workday resumes  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 47  workday resumes  Srikanth (WORKDAY hCM Consultant)\t           ...
# 48  workday resumes  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 49  workday resumes  Vinay kumar .v\nWorkday Functional Consultant\...

# %%
resume_data[resume_data.Category == 'Internship']
# Out:
#       Category                                        Raw_Details
# 50  Internship  Name: Ravali P \n\n\n\n                       ...
# 51  Internship  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...

# %%
resume_data.isnull().sum()
# Out:
# Category       0
# Raw_Details    0
# dtype: int64

# %% [markdown]
# # Number of Words

# %%
resume_data['Word_Count'] = resume_data['Raw_Details'].apply(lambda x: len(str(x).split(" ")))
resume_data[['Raw_Details','Word_Count']].head()
# Out:
#                                          Raw_Details  Word_Count
# 0  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...        1023
# 1  Classification: Internal\n\nClassification: In...         558
# 2  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...         455
# 3  PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...         918
# 4  PeopleSoft Administration\n\n \n\nVivekanand S...        2585

# %% [markdown]
# # Number of Characters

# %%
resume_data['Char_Count'] = resume_data['Raw_Details'].str.len() ## this also includes spaces
resume_data[['Raw_Details','Char_Count']].head()
# Out:
#                                          Raw_Details  Char_Count
# 0  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...        8010
# 1  Classification: Internal\n\nClassification: In...        4917
# 2  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...        3800
# 3  PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...        7943
# 4  PeopleSoft Administration\n\n \n\nVivekanand S...       16112

# %% [markdown]
# # Number of Stopwords

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
resume_data['Stopwords'] = resume_data['Raw_Details'].apply(lambda x: len([x for x in x.split() if x in stop]))
resume_data[['Raw_Details','Stopwords']].head()
# Out:
#                                          Raw_Details  Stopwords
# 0  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...        190
# 1  Classification: Internal\n\nClassification: In...        114
# 2  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...         86
# 3  PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...        225
# 4  PeopleSoft Administration\n\n \n\nVivekanand S...        520

# %% [markdown]
# # Number of Numerics

# %%
resume_data['Numerics'] = resume_data['Raw_Details'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
resume_data[['Raw_Details','Numerics']].head()
# Out:
#                                          Raw_Details  Numerics
# 0  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...         4
# 1  Classification: Internal\n\nClassification: In...         7
# 2  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...        15
# 3  PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...         4
# 4  PeopleSoft Administration\n\n \n\nVivekanand S...        17

# %%
resume_data
# Out:
#                            Category  \
# 0                Peoplesoft resumes
# 1                Peoplesoft resumes
# 2                Peoplesoft resumes
# 3                Peoplesoft resumes
# 4                Peoplesoft resumes
# 5                Peoplesoft resumes
# 6                Peoplesoft resumes
# 7                Peoplesoft resumes
# 8                Peoplesoft resumes
# 9                Peoplesoft resumes
# 10               React JS Developer
# 11               React JS Developer
# 12               React JS Developer
# 13               React JS Developer
# 14               React JS Developer
# 15               React JS Developer
# 16               React JS Developer
# 17               React JS Developer
# 18               React JS Developer
# 19               React JS Developer
# 20               React JS Developer
# 21               React JS Developer
# 22               React JS Developer
# 23               React JS Developer
# 24               React JS Developer
# ...

# %% [markdown]
# # Text Pre-Processing

# %%
def preprocess(sentence):
    sentence = str(sentence)
    sentence = sentence.lower()
    sentence = sentence.replace('{html}',"") 
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', sentence)
    rem_url = re.sub(r'http\S+', '',cleantext)
    rem_num = re.sub('[0-9]+', '', rem_url)
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(rem_num)  
    filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')]

    return " ".join(filtered_words)

# %%
import re
from nltk.tokenize import RegexpTokenizer
resume_data = pd.read_csv('Raw_Resume.csv')
resume_data['Resume_Details'] = resume_data.Raw_Details.apply(lambda x: preprocess(x))

# %%
resume_data
# Out:
#                            Category  \
# 0                Peoplesoft resumes
# 1                Peoplesoft resumes
# 2                Peoplesoft resumes
# 3                Peoplesoft resumes
# 4                Peoplesoft resumes
# 5                Peoplesoft resumes
# 6                Peoplesoft resumes
# 7                Peoplesoft resumes
# 8                Peoplesoft resumes
# 9                Peoplesoft resumes
# 10               React JS Developer
# 11               React JS Developer
# 12               React JS Developer
# 13               React JS Developer
# 14               React JS Developer
# 15               React JS Developer
# 16               React JS Developer
# 17               React JS Developer
# 18               React JS Developer
# 19               React JS Developer
# 20               React JS Developer
# 21               React JS Developer
# 22               React JS Developer
# 23               React JS Developer
# 24               React JS Developer
# ...

# %%
resume_data.drop(['Raw_Details'], axis = 1, inplace = True)
resume_data
# Out:
#                            Category  \
# 0                Peoplesoft resumes
# 1                Peoplesoft resumes
# 2                Peoplesoft resumes
# 3                Peoplesoft resumes
# 4                Peoplesoft resumes
# 5                Peoplesoft resumes
# 6                Peoplesoft resumes
# 7                Peoplesoft resumes
# 8                Peoplesoft resumes
# 9                Peoplesoft resumes
# 10               React JS Developer
# 11               React JS Developer
# 12               React JS Developer
# 13               React JS Developer
# 14               React JS Developer
# 15               React JS Developer
# 16               React JS Developer
# 17               React JS Developer
# 18               React JS Developer
# 19               React JS Developer
# 20               React JS Developer
# 21               React JS Developer
# 22               React JS Developer
# 23               React JS Developer
# 24               React JS Developer
# ...

# %%
resume_data.to_csv('Cleaned_Resumes.csv', index = False)

# %%
resume_data = pd.read_csv('Cleaned_Resumes.csv')
resume_data
# Out:
#                            Category  \
# 0                Peoplesoft resumes
# 1                Peoplesoft resumes
# 2                Peoplesoft resumes
# 3                Peoplesoft resumes
# 4                Peoplesoft resumes
# 5                Peoplesoft resumes
# 6                Peoplesoft resumes
# 7                Peoplesoft resumes
# 8                Peoplesoft resumes
# 9                Peoplesoft resumes
# 10               React JS Developer
# 11               React JS Developer
# 12               React JS Developer
# 13               React JS Developer
# 14               React JS Developer
# 15               React JS Developer
# 16               React JS Developer
# 17               React JS Developer
# 18               React JS Developer
# 19               React JS Developer
# 20               React JS Developer
# 21               React JS Developer
# 22               React JS Developer
# 23               React JS Developer
# 24               React JS Developer
# ...

# %%
resume_data.Resume_Details
# Out:
# 0     anubhav kumar singh core competencies scriptin...
# 1     classification internal classification interna...
# 2     sirazuddin bangalore india sirazuddin bangalor...
# 3     peoplesoft admin varkala vikas career objectiv...
# 4     peoplesoft administration vivekanand sayana ca...
# 5     hari narayana professional summary years exper...
# 6     murali professional summary years experience p...
# 7     priyabrata hota career objective pursuing peop...
# 8     tanna sujatha objective seeking challenging ro...
# 9     address manyata tech park nagavara bangalore l...
# 10    kanumuru deepak reddy career objective secure ...
# 11    haripriya battina experience developer reactjs...
# 12    kamalakar reddy linked professional summary ye...
# 13    naveen sadhu title software developer location...
# 14    pragnya pattnaik expertise around years experi...
# 15    sarala madasu sarala madasu sri geethika prest...
# 16    thirupathamma balla summary year experience re...
# ...

# %%
Details = resume_data.Resume_Details
Details
# Out:
# 0     anubhav kumar singh core competencies scriptin...
# 1     classification internal classification interna...
# 2     sirazuddin bangalore india sirazuddin bangalor...
# 3     peoplesoft admin varkala vikas career objectiv...
# 4     peoplesoft administration vivekanand sayana ca...
# 5     hari narayana professional summary years exper...
# 6     murali professional summary years experience p...
# 7     priyabrata hota career objective pursuing peop...
# 8     tanna sujatha objective seeking challenging ro...
# 9     address manyata tech park nagavara bangalore l...
# 10    kanumuru deepak reddy career objective secure ...
# 11    haripriya battina experience developer reactjs...
# 12    kamalakar reddy linked professional summary ye...
# 13    naveen sadhu title software developer location...
# 14    pragnya pattnaik expertise around years experi...
# 15    sarala madasu sarala madasu sri geethika prest...
# 16    thirupathamma balla summary year experience re...
# ...

# %%
# Joining the list into one string/text
text = ' '.join(Details)
text
# Out:
# 'anubhav kumar singh core competencies scripting shell scripting application peoplesoft hcm financials operating system linux windows web app servers weblogic tuxedo rdbms oracle repository github core competencies scripting shell scripting application peoplesoft hcm financials operating system linux windows web app servers weblogic tuxedo rdbms oracle repository github work globally competitive environment challenging assignments shall yield twin benefits job satisfaction steady paced professional growth professional experience current hcl current role system admin offshore skills shell scripting linux peoplesoft administration github managing peoplesoft hcm peoplesoft fscm production environments along support environments installed linux windows involved day day activities project migration database refresh system admin changes tax updates etc troubleshooting various servers like application servers web servers process scheduler servers applying tuxedo weblogic middleware cpu patc
# ...

# %%
from nltk.tokenize import word_tokenize
text_tokens = word_tokenize(text)
text_tokens
# Out:
# ['anubhav',
#  'kumar',
#  'singh',
#  'core',
#  'competencies',
#  'scripting',
#  'shell',
#  'scripting',
#  'application',
#  'peoplesoft',
#  'hcm',
#  'financials',
#  'operating',
#  'system',
#  'linux',
#  'windows',
#  'web',
#  'app',
#  'servers',
#  'weblogic',
#  'tuxedo',
#  'rdbms',
#  'oracle',
#  'repository',
#  'github',
#  'core',
#  'competencies',
#  'scripting',
#  'shell',
#  'scripting',
#  'application',
#  'peoplesoft',
#  'hcm',
#  'financials',
#  'operating',
#  'system',
#  'linux',
#  'windows',
#  'web',
#  'app',
#  'servers',
#  'weblogic',
#  'tuxedo',
#  'rdbms',
#  'oracle',
#  'repository',
#  'github',
#  'work',
#  'globally',
#  'competitive',
#  'environment',
#  'challenging',
#  'assignments',
#  'shall',
#  'yield',
#  'twin',
#  'benefits',
#  'job',
#  'satisfaction',
#  'steady',
#  'paced',
#  'professional',
#  'growth',
#  'professional',
#  'experience',
#  'current',
#  'hcl',
#  'current',
#  'role',
#  'system',
#  'admin',
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tag import pos_tag

def filter_nouns_and_verbs(text):
    sentences = sent_tokenize(text)
    filtered_tokens = []
    for sentence in sentences:
        tokens = word_tokenize(sentence)
        tagged_tokens = pos_tag(tokens)
        filtered_tokens.extend(word for word, pos in tagged_tokens if pos.startswith('NN') or pos.startswith('VB'))
        return filtered_tokens

# %%
nouns_verbs = filter_nouns_and_verbs(text)
print(nouns_verbs)
# Out:
# ['kumar', 'singh', 'core', 'competencies', 'scripting', 'shell', 'scripting', 'application', 'hcm', 'financials', 'operating', 'system', 'windows', 'web', 'app', 'servers', 'weblogic', 'rdbms', 'oracle', 'repository', 'github', 'core', 'competencies', 'scripting', 'shell', 'scripting', 'application', 'hcm', 'financials', 'operating', 'system', 'windows', 'web', 'app', 'servers', 'weblogic', 'rdbms', 'oracle', 'repository', 'github', 'work', 'environment', 'challenging', 'assignments', 'yield', 'benefits', 'job', 'satisfaction', 'paced', 'growth', 'experience', 'hcl', 'role', 'system', 'admin', 'skills', 'shell', 'scripting', 'linux', 'administration', 'github', 'managing', 'hcm', 'fscm', 'production', 'environments', 'support', 'environments', 'installed', 'windows', 'involved', 'day', 'day', 'activities', 'project', 'migration', 'database', 'refresh', 'system', 'changes', 'tax', 'updates', 'troubleshooting', 'servers', 'application', 'servers', 'web', 'servers', 'process', 'schedule
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X = cv.fit_transform(nouns_verbs)
sum_words = X.sum(axis=0)

words_freq = [(word,sum_words[0,idx]) for word, idx in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)

wd_df = pd.DataFrame(words_freq)
wd_df.columns = ['Words','Count']
wd_df[0:15]
# Out:
#           Words  Count
# 0    experience    297
# 1         using    253
# 2   application    204
# 3          data    178
# 4       project    177
# 5       reports    170
# 6      business    165
# 7           sql    155
# 8        server    146
# 9     knowledge    136
# 10       skills    118
# 11       system    116
# 12          web    112
# 13      process    105
# 14       client    105

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
resume_data['Category'].value_counts().sort_index().plot(kind='bar', figsize=(12, 6))
plt.show()

# %%
file_path   = r'C:\\Users\\admin\\Desktop\\Project_Docs\\Resumes\\'
doc_file    = []
pdf_file    = []
docx_file   = []
folder_name = []

for folder in os.listdir(file_path):
    folder_path = file_path+folder
    for file in os.listdir(folder_path):
        if file.endswith('.doc'):
            doc_file.append(file)
            folder_name.append(folder)
        elif file.endswith('.docx'):
            docx_file.append(file)
            folder_name.append(folder)
        else:
            pdf_file.append(file)
            folder_name.append(folder)

# %%
print('Number of .doc Files  = {}'.format(len(doc_file)),'\n'
      'Number of .pdf Files  = {}'.format(len(pdf_file)),'\n'
      'Number of .docx Files = {}'.format(len(docx_file)))
# Out:
# Number of .doc Files  = 26
# Number of .pdf Files  = 1
# Number of .docx Files = 52

# %%
print("Total Number of Files = ", len(docx_file)+len(doc_file)+len(pdf_file))
# Out:
# Total Number of Files =  79

# %%
file_types = ['.docx File', '.doc File', '.pdf File']
file_counts = [len(docx_file), len(doc_file), len(pdf_file)]

plt.figure(figsize=(9, 6), dpi=100)
sns.barplot(x=file_types, y=file_counts)

plt.xlabel('Extensions', size=16, fontweight='bold')
plt.ylabel('Frequency', size=16, fontweight='bold')
plt.title('Type of Files in Resumes', fontsize=18, fontweight='bold')

for i, count in enumerate(file_counts):
    plt.text(i, count, str(count), color='black', fontweight='bold', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
sizes = [len(docx_file), len(doc_file), len(pdf_file)]
labels = ['.docx Files', '.doc Files', '.pdf File']
colors = ['orange', 'green', 'white']
explode = (0.0, 0.0, 0.01)

plt.figure(figsize=(8, 8), dpi=100)

plt.pie(sizes, colors=colors, labels=labels, autopct='%1.0f%%', pctdistance=0.85, 
        explode=explode, startangle=0, textprops={'size': 'large', 'fontweight': 'bold'})

plt.title('Percentage of Extensions in Resumes', fontsize=18, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
text = " ".join(x for x in wd_df.Words)
text
# Out:
# 'experience using application data project reports business sql server knowledge skills system web process client workday working tools creating database integrations development support worked integration servers services involved people created report design used developer role react responsibilities work studio team testing security management date hcm windows information technologies code environment fields oracle core production developed issues applications software css years javascript reporting domains functions requirement based html requirements scheduler developing consultant tables technology queries end day languages custom education till components systems change name roles college test bootstrap performance description maintenance engineering eib projects implementation expertise job status details fscm peoplesoft organization objects interface procedures compensation xml packages load customer activities peopletools hyderabad hands environments transformation troubles
# ...

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    plt.figure(figsize=(15, 30))
    plt.imshow(wordcloud) 
    plt.axis("off");

# %%
stopwords = STOPWORDS
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
# ...

# %%
wordcloud = WordCloud(width = 3000, height = 2000, background_color='black', max_words=100,colormap='Set2',stopwords=stopwords).generate(text)
plot_cloud(wordcloud)

# %% [markdown]
# # Import Dataset

# %%
resume_data = pd.read_csv('Cleaned_Resumes.csv')
resume_data
# Out:
#                            Category  \
# 0                Peoplesoft resumes
# 1                Peoplesoft resumes
# 2                Peoplesoft resumes
# 3                Peoplesoft resumes
# 4                Peoplesoft resumes
# 5                Peoplesoft resumes
# 6                Peoplesoft resumes
# 7                Peoplesoft resumes
# 8                Peoplesoft resumes
# 9                Peoplesoft resumes
# 10               React JS Developer
# 11               React JS Developer
# 12               React JS Developer
# 13               React JS Developer
# 14               React JS Developer
# 15               React JS Developer
# 16               React JS Developer
# 17               React JS Developer
# 18               React JS Developer
# 19               React JS Developer
# 20               React JS Developer
# 21               React JS Developer
# 22               React JS Developer
# 23               React JS Developer
# 24               React JS Developer
# ...

# %% [markdown]
# # Model Building

# %%
X = resume_data['Resume_Details'].values
X
# Out:
# array(['anubhav kumar singh core competencies scripting shell scripting application peoplesoft hcm financials operating system linux windows web app servers weblogic tuxedo rdbms oracle repository github core competencies scripting shell scripting application peoplesoft hcm financials operating system linux windows web app servers weblogic tuxedo rdbms oracle repository github work globally competitive environment challenging assignments shall yield twin benefits job satisfaction steady paced professional growth professional experience current hcl current role system admin offshore skills shell scripting linux peoplesoft administration github managing peoplesoft hcm peoplesoft fscm production environments along support environments installed linux windows involved day day activities project migration database refresh system admin changes tax updates etc troubleshooting various servers like application servers web servers process scheduler servers applying tuxedo weblogic middleware c
# ...

# %%
Y = resume_data['Category'].values
Y
# Out:
# array(['Peoplesoft resumes', 'Peoplesoft resumes', 'Peoplesoft resumes',
#        'Peoplesoft resumes', 'Peoplesoft resumes', 'Peoplesoft resumes',
#        'Peoplesoft resumes', 'Peoplesoft resumes', 'Peoplesoft resumes',
#        'Peoplesoft resumes', 'React JS Developer', 'React JS Developer',
#        'React JS Developer', 'React JS Developer', 'React JS Developer',
#        'React JS Developer', 'React JS Developer', 'React JS Developer',
#        'React JS Developer', 'React JS Developer', 'React JS Developer',
#        'React JS Developer', 'React JS Developer', 'React JS Developer',
#        'React JS Developer', 'React JS Developer', 'React JS Developer',
#        'React JS Developer', 'SQL Developer Lightning insight',
#        'SQL Developer Lightning insight',
#        'SQL Developer Lightning insight',
#        'SQL Developer Lightning insight',
#        'SQL Developer Lightning insight',
#        'SQL Developer Lightning insight',
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, random_state=45, test_size=0.25)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((39,), (13,), (39,), (13,))

# %% [markdown]
# # Vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf_vector = TfidfVectorizer(sublinear_tf=True,stop_words='english')

# %%
x_train = tfidf_vector.fit_transform(x_train)
x_test = tfidf_vector.transform(x_test)

# %%
x_train.shape, x_test.shape
# Out:
# ((39, 2652), (13, 2652))

# %%
print(y_train),print(y_test)
# Out:
# ['React JS Developer' 'React JS Developer' 'workday resumes'
#  'React JS Developer' 'SQL Developer Lightning insight' 'Internship'
#  'React JS Developer' 'SQL Developer Lightning insight'
#  'Peoplesoft resumes' 'SQL Developer Lightning insight' 'workday resumes'
#  'React JS Developer' 'React JS Developer' 'workday resumes'
#  'React JS Developer' 'workday resumes' 'workday resumes' 'Internship'
#  'workday resumes' 'workday resumes' 'React JS Developer'
#  'SQL Developer Lightning insight' 'React JS Developer'
#  'SQL Developer Lightning insight' 'React JS Developer' 'workday resumes'
#  'React JS Developer' 'Peoplesoft resumes' 'React JS Developer'
#  'Peoplesoft resumes' 'React JS Developer' 'Peoplesoft resumes'
#  'SQL Developer Lightning insight' 'React JS Developer'
#  'SQL Developer Lightning insight' 'SQL Developer Lightning insight'
#  'Peoplesoft resumes' 'SQL Developer Lightning insight'
#  'React JS Developer']
# ...

# %% [markdown]
# # Classification Models

# %% [markdown]
# # KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, classification_report, precision_score, recall_score
from sklearn.model_selection import cross_val_score

# %%
model_knn = KNeighborsClassifier(n_neighbors=5)

model_knn.fit(x_train, y_train)
y_pred = model_knn.predict(x_test)

accuracy_knn = accuracy_score(y_test, y_pred)

print(f'Accuracy of training set: {model_knn.score(x_train, y_train):}')

print(f'Accuracy of test set: {model_knn.score(x_test, y_test):}')

print(f"Classification report for classifier {model_knn}:\n{classification_report(y_test, y_pred)}\n")

precision_knn = round(precision_score(y_test, y_pred, average='macro'), 2)
recall_knn = round(recall_score(y_test, y_pred, average='macro'), 2)
f1_knn = round(f1_score(y_test, y_pred, average='macro'), 2)
accuracy_knn = round(accuracy_score(y_test, y_pred), 2)
# Out:
# Accuracy of training set: 0.9230769230769231
# Accuracy of test set: 0.9230769230769231
# Classification report for classifier KNeighborsClassifier():
#                                  precision    recall  f1-score   support
#
#              Peoplesoft resumes       1.00      0.80      0.89         5
#              React JS Developer       1.00      1.00      1.00         3
# SQL Developer Lightning insight       1.00      1.00      1.00         2
#                 workday resumes       0.75      1.00      0.86         3
#
#                        accuracy                           0.92        13
#                       macro avg       0.94      0.95      0.94        13
#                    weighted avg       0.94      0.92      0.92        13
# ...

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold, cross_val_score

# %%
model_DT = DecisionTreeClassifier(criterion='gini', max_depth = 3)

model_DT.fit(x_train, y_train)

# Make predictions on the test data
y_pred = model_DT.predict(x_test)

accuracy_DT = accuracy_score(y_test, y_pred)

print(f'Accuracy of training set: {model_DT.score(x_train, y_train):.2f}')

print(f'Accuracy of test set: {model_DT.score(x_test, y_test):.2f}')

print(f"Classification report for classifier {model_DT}:\n{classification_report(y_test, y_pred)}\n")


precision_DT = round(precision_score(y_test, y_pred, average='macro'), 2)
recall_DT = round(recall_score(y_test, y_pred, average='macro'), 2)
f1_DT = round(f1_score(y_test, y_pred, average='macro'), 2)
accuracy_DT = round(accuracy_score(y_test, y_pred), 2)
# Out:
# Accuracy of training set: 0.97
# Accuracy of test set: 0.92
# Classification report for classifier DecisionTreeClassifier(max_depth=3):
#                                  precision    recall  f1-score   support
#
#              Peoplesoft resumes       0.83      1.00      0.91         5
#              React JS Developer       1.00      0.67      0.80         3
# SQL Developer Lightning insight       1.00      1.00      1.00         2
#                 workday resumes       1.00      1.00      1.00         3
#
#                        accuracy                           0.92        13
#                       macro avg       0.96      0.92      0.93        13
#                    weighted avg       0.94      0.92      0.92        13

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_RF = RandomForestClassifier(n_estimators=200,max_samples = 0.25)

model_RF.fit(x_train, y_train)

y_pred = model_RF.predict(x_test)

accuracy_RF = accuracy_score(y_test, y_pred)

print(f'Accuracy of training set: {model_RF.score(x_train, y_train):.2f}')

print(f'Accuracy of test set: {model_RF.score(x_test, y_test):.2f}')

print(f"Classification report for classifier {model_RF}:\n{classification_report(y_test, y_pred)}\n")


precision_RF = round(precision_score(y_test, y_pred, average='macro'), 2)
recall_RF = round(recall_score(y_test, y_pred, average='macro'), 2)
f1_RF = round(f1_score(y_test, y_pred, average='macro'), 2)
accuracy_RF = round(accuracy_score(y_test, y_pred), 2)
# Out:
# Accuracy of training set: 0.90
# Accuracy of test set: 0.69
# Classification report for classifier RandomForestClassifier(max_samples=0.25, n_estimators=200):
#                                  precision    recall  f1-score   support
#
#              Peoplesoft resumes       1.00      0.40      0.57         5
#              React JS Developer       0.43      1.00      0.60         3
# SQL Developer Lightning insight       1.00      0.50      0.67         2
#                 workday resumes       1.00      1.00      1.00         3
#
#                        accuracy                           0.69        13
#                       macro avg       0.86      0.72      0.71        13
#                    weighted avg       0.87      0.69      0.69        13

# %% [markdown]
# # Support Vectore Machine (SVM) Classifier

# %%
from sklearn.svm import SVC

# %%
model_svm = SVC(kernel='linear')

model_svm.fit(x_train, y_train)
y_pred = model_svm.predict(x_test)

accuracy_svm = accuracy_score(y_test, y_pred)

print(f'Accuracy of training set: {model_svm.score(x_train, y_train):.2f}')

print(f'Accuracy of test set: {model_svm.score(x_test, y_test):.2f}')

print(f"Classification report for classifier {model_svm}:\n{classification_report(y_test, y_pred)}\n")


precision_svm = round(precision_score(y_test, y_pred, average='macro'),2)
recall_svm = round(recall_score(y_test, y_pred, average='macro'),2)
f1_svm = round(f1_score(y_test, y_pred, average='macro'),2)
accuracy_svm = round(accuracy_score(y_test, y_pred),2)
# Out:
# Accuracy of training set: 1.00
# Accuracy of test set: 0.85
# Classification report for classifier SVC(kernel='linear'):
#                                  precision    recall  f1-score   support
#
#              Peoplesoft resumes       1.00      0.60      0.75         5
#              React JS Developer       0.75      1.00      0.86         3
# SQL Developer Lightning insight       0.67      1.00      0.80         2
#                 workday resumes       1.00      1.00      1.00         3
#
#                        accuracy                           0.85        13
#                       macro avg       0.85      0.90      0.85        13
#                    weighted avg       0.89      0.85      0.84        13

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_lgr = LogisticRegression()

model_lgr.fit(x_train, y_train)
y_pred = model_lgr.predict(x_test)

accuracy_lgr = accuracy_score(y_test, y_pred)

print(f'Accuracy of training set: {model_lgr.score(x_train, y_train):.2f}')

print(f'Accuracy of test set: {model_lgr.score(x_test, y_test):.2f}')

print(f"Classification report for classifier {model_lgr}:\n{classification_report(y_test, y_pred)}\n")

precision_lgr = round(precision_score(y_test, y_pred, average='macro'), 2)
recall_lgr = round(recall_score(y_test, y_pred, average='macro'), 2)
f1_lgr = round(f1_score(y_test, y_pred, average='macro'), 2)
accuracy_lgr = round(accuracy_score(y_test, y_pred), 2)
# Out:
# Accuracy of training set: 0.92
# Accuracy of test set: 0.77
# Classification report for classifier LogisticRegression():
#                                  precision    recall  f1-score   support
#
#              Peoplesoft resumes       1.00      0.40      0.57         5
#              React JS Developer       0.50      1.00      0.67         3
# SQL Developer Lightning insight       1.00      1.00      1.00         2
#                 workday resumes       1.00      1.00      1.00         3
#
#                        accuracy                           0.77        13
#                       macro avg       0.88      0.85      0.81        13
#                    weighted avg       0.88      0.77      0.76        13

# %% [markdown]
# # Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier

# %%
model_bagg = BaggingClassifier(DecisionTreeClassifier(), max_samples=0.5, max_features=0.5)

model_bagg.fit(x_train, y_train)
y_pred = model_bagg.predict(x_test)


accuracy_bagg = accuracy_score(y_test, y_pred)

print(f'Accuracy of training set: {model_bagg.score(x_train, y_train):.2f}')

print(f'Accuracy of test set: {model_bagg.score(x_test, y_test):.2f}')

print(f"Classification report for classifier {model_bagg}:\n{classification_report(y_test, y_pred)}\n")

precision_bagg = round(precision_score(y_test, y_pred, average='macro'), 2)
recall_bagg = round(recall_score(y_test, y_pred, average='macro'), 2)
f1_bagg = round(f1_score(y_test, y_pred, average='macro'), 2)
accuracy_bagg = round(accuracy_score(y_test, y_pred), 2)
# Out:
# Accuracy of training set: 1.00
# Accuracy of test set: 0.85
# Classification report for classifier BaggingClassifier(base_estimator=DecisionTreeClassifier(), max_features=0.5,
#                   max_samples=0.5):
#                                  precision    recall  f1-score   support
#
#              Peoplesoft resumes       1.00      0.60      0.75         5
#              React JS Developer       0.75      1.00      0.86         3
# SQL Developer Lightning insight       0.67      1.00      0.80         2
#                 workday resumes       1.00      1.00      1.00         3
#
#                        accuracy                           0.85        13
#                       macro avg       0.85      0.90      0.85        13
#                    weighted avg       0.89      0.85      0.84        13

# %% [markdown]
# # Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
model_GradientBoost = GradientBoostingClassifier(n_estimators=300,learning_rate = 1, max_depth=10,)

model_GradientBoost.fit(x_train, y_train)
y_pred = model_GradientBoost.predict(x_test)


accuracy_GradientBoost = accuracy_score(y_test, y_pred)


print(f'Accuracy of training set: {model_GradientBoost.score(x_train, y_train):.2f}')

print(f'Accuracy of test set: {model_GradientBoost.score(x_test, y_test):.2f}')

print(f"Classification report for classifier {model_GradientBoost}:\n{classification_report(y_test, y_pred)}\n")

precision_GradientBoost = round(precision_score(y_test, y_pred, average='macro'), 2)
recall_GradientBoost = round(recall_score(y_test, y_pred, average='macro'), 2)
f1_GradientBoost = round(f1_score(y_test, y_pred, average='macro'), 2)
accuracy_GradientBoost = round(accuracy_score(y_test, y_pred), 2)
# Out:
# Accuracy of training set: 1.00
# Accuracy of test set: 0.92
# Classification report for classifier GradientBoostingClassifier(learning_rate=1, max_depth=10, n_estimators=300):
#                                  precision    recall  f1-score   support
#
#              Peoplesoft resumes       1.00      1.00      1.00         5
#              React JS Developer       1.00      0.67      0.80         3
# SQL Developer Lightning insight       0.67      1.00      0.80         2
#                 workday resumes       1.00      1.00      1.00         3
#
#                        accuracy                           0.92        13
#                       macro avg       0.92      0.92      0.90        13
#                    weighted avg       0.95      0.92      0.92        13

# %% [markdown]
# # Naive Bayes Classifier

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model_NB = MultinomialNB()

model_NB.fit(x_train, y_train)
y_pred = model_NB.predict(x_test)

accuracy_NB = accuracy_score(y_test, y_pred)

print(f'Accuracy of training set: {model_NB.score(x_train, y_train):.2f}')

print(f'Accuracy of test set: {model_NB.score(x_test, y_test):.2f}')

print(f"Classification report for classifier {model_NB}:\n{classification_report(y_test, y_pred)}\n")


precision_NB = round(precision_score(y_test, y_pred, average='macro'), 2)
recall_NB = round(recall_score(y_test, y_pred, average='macro'), 2)
f1_NB = round(f1_score(y_test, y_pred, average='macro'), 2)
accuracy_NB = round(accuracy_score(y_test, y_pred), 2)
# Out:
# Accuracy of training set: 0.90
# Accuracy of test set: 0.62
# Classification report for classifier MultinomialNB():
#                                  precision    recall  f1-score   support
#
#              Peoplesoft resumes       0.00      0.00      0.00         5
#              React JS Developer       0.38      1.00      0.55         3
# SQL Developer Lightning insight       1.00      1.00      1.00         2
#                 workday resumes       1.00      1.00      1.00         3
#
#                        accuracy                           0.62        13
#                       macro avg       0.59      0.75      0.64        13
#                    weighted avg       0.47      0.62      0.51        13
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# # Model Evaluation

# %%
import pandas as pd

Evaluation = {
    "Models": [
        "KNN Classifier",
        "DecisionTree Classifier",
        "RandomForest Classifier",
        "SVM Classifier",
        "Logistic Regression",
        "Bagging Classifier",
        "Gradient Boosting Classifier",
        "Naive Bayes Classifier"
    ],
    "Train_Accuracy(%)": [
        model_knn.score(x_train, y_train),
        model_DT.score(x_train, y_train),
        model_RF.score(x_train, y_train),
        model_svm.score(x_train, y_train),
        model_lgr.score(x_train, y_train),
        model_bagg.score(x_train, y_train),
        model_GradientBoost.score(x_train, y_train),
        model_NB.score(x_train, y_train)],
    
    "Test_Accuracy(%)": [
        accuracy_knn,
        accuracy_DT,
        accuracy_RF,
        accuracy_svm,
        accuracy_lgr,
        accuracy_bagg,
        accuracy_GradientBoost,
        accuracy_NB],
    
    "Precision(%)": [
        precision_knn,
        precision_DT,
        precision_RF,
        precision_svm,
        precision_lgr,
        precision_bagg,
        precision_GradientBoost,
        precision_NB],
    "Recall(%)": [
        recall_knn,
        recall_DT,
        recall_RF,
        recall_svm,
        recall_lgr,
        recall_bagg,
        recall_GradientBoost,
        recall_NB
    ],
    
    "F1-Score(%)": [
        f1_knn,
        f1_DT,
        f1_RF,
        f1_svm,
        f1_lgr,
        f1_bagg,
        f1_GradientBoost,
        f1_NB]
}

table = pd.DataFrame(Evaluation)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
table
# Out:
#                          Models  Train_Accuracy(%)  Test_Accuracy(%)  \
# 0                KNN Classifier           0.923077              0.92
# 1       DecisionTree Classifier           0.974359              0.92
# 2       RandomForest Classifier           0.897436              0.69
# 3                SVM Classifier           1.000000              0.85
# 4           Logistic Regression           0.923077              0.77
# 5            Bagging Classifier           1.000000              0.92
# 6  Gradient Boosting Classifier           1.000000              0.92
# 7        Naive Bayes Classifier           0.897436              0.62
#
#    Precision(%)  Recall(%)  F1-Score(%)
# 0          0.94       0.95         0.94
# 1          0.96       0.92         0.93
# 2          0.86       0.72         0.71
# 3          0.85       0.90         0.85
# 4          0.88       0.85         0.81
# 5          0.92       0.92         0.90
# 6          0.92       0.92         0.90
# ...

# %%
model_names = ["KNN", "DecisionTree",
               "RandomForest", "SVM",
               "Logistic Regression",
               "Bagging", "AdaBoost",
               "Gradient Boosting",
               "Naive Bayes"]
Test_accuracies = [accuracy_knn*100, accuracy_DT*100,
                   accuracy_RF*100, accuracy_svm*100,
                   accuracy_lgr*100, accuracy_bagg*100,
                   accuracy_GradientBoost*100,
                   accuracy_NB*100]

Train_accuracies = [model_knn.score(x_train, y_train)*100,
                    model_DT.score(x_train, y_train)*100,
                    model_RF.score(x_train, y_train)*100,
                    model_svm.score(x_train, y_train)*100,
                    model_lgr.score(x_train, y_train)*100,
                    model_bagg.score(x_train, y_train)*100,
                    model_GradientBoost.score(x_train, y_train)*100,
                    model_NB.score(x_train, y_train)*100]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
model_names
# Out:
# ['KNN',
#  'DecisionTree',
#  'RandomForest',
#  'SVM',
#  'Logistic Regression',
#  'Bagging',
#  'AdaBoost',
#  'Gradient Boosting',
#  'Naive Bayes']

# %%
Test_accuracies
# Out:
# [92.0, 92.0, 69.0, 85.0, 77.0, 92.0, 92.0, 62.0]

# %%
Train_accuracies
# Out:
# [92.3076923076923,
#  97.43589743589743,
#  94.87179487179486,
#  100.0,
#  92.3076923076923,
#  94.87179487179486,
#  100.0,
#  89.74358974358975]

# %% [markdown]
# # Train and Test Accuracy Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

model_names = ["KNN", "Decision T", "Random F", "SVM ", "Logistic", "Bagging", "Grad Boost","Naive Bayes"]
Test_accuracies = [accuracy_knn*100, 
                   accuracy_DT*100, 
                   accuracy_RF*100, 
                   accuracy_svm*100, 
                   accuracy_lgr*100, 
                   accuracy_bagg*100, 
                   accuracy_GradientBoost*100, 
                   accuracy_NB*100]
Train_accuracies = [model_knn.score(x_train, y_train)*100, 
                    model_DT.score(x_train, y_train)*100, 
                    model_RF.score(x_train, y_train)*100, 
                    model_svm.score(x_train, y_train)*100, 
                    model_lgr.score(x_train, y_train)*100, 
                    model_bagg.score(x_train, y_train)*100, 
                    model_GradientBoost.score(x_train, y_train)*100, 
                    model_NB.score(x_train, y_train)*100]

plt.figure(figsize=(12, 6), dpi=500)
x_pos = np.arange(len(model_names))
bar_width = 0.4

plt.bar(x_pos - bar_width/2, Train_accuracies, width=bar_width, label='Train', color="orange")
plt.bar(x_pos + bar_width/2, Test_accuracies, width=bar_width, label='Test', color="blue")

plt.xlabel("Classifiers", fontsize=16, fontweight='bold')
plt.ylabel("Accuracy", fontsize=16, fontweight='bold')
plt.title("Model Accuracy Scores", fontsize=18, fontweight='bold')

plt.xticks(x_pos, model_names, rotation=10)
plt.legend()

for i, acc_train in enumerate(Train_accuracies):
    plt.text(x_pos[i] - bar_width/2, acc_train, f"{acc_train:.2f}%", ha='center', va='bottom', fontsize=7)

for i, acc_test in enumerate(Test_accuracies):
    plt.text(x_pos[i] + bar_width/2, acc_test, f"{acc_test:.2f}%", ha='center', va='bottom', fontsize=7)

plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %% [markdown]
# # Model Deployment

# %%
X = resume_data['Resume_Details'].values
X
# Out:
# array(['anubhav kumar singh core competencies scripting shell scripting application peoplesoft hcm financials operating system linux windows web app servers weblogic tuxedo rdbms oracle repository github core competencies scripting shell scripting application peoplesoft hcm financials operating system linux windows web app servers weblogic tuxedo rdbms oracle repository github work globally competitive environment challenging assignments shall yield twin benefits job satisfaction steady paced professional growth professional experience current hcl current role system admin offshore skills shell scripting linux peoplesoft administration github managing peoplesoft hcm peoplesoft fscm production environments along support environments installed linux windows involved day day activities project migration database refresh system admin changes tax updates etc troubleshooting various servers like application servers web servers process scheduler servers applying tuxedo weblogic middleware c
# ...

# %%
YT = resume_data['Category'].values
YT
# Out:
# array(['Peoplesoft resumes', 'Peoplesoft resumes', 'Peoplesoft resumes',
#        'Peoplesoft resumes', 'Peoplesoft resumes', 'Peoplesoft resumes',
#        'Peoplesoft resumes', 'Peoplesoft resumes', 'Peoplesoft resumes',
#        'Peoplesoft resumes', 'React JS Developer', 'React JS Developer',
#        'React JS Developer', 'React JS Developer', 'React JS Developer',
#        'React JS Developer', 'React JS Developer', 'React JS Developer',
#        'React JS Developer', 'React JS Developer', 'React JS Developer',
#        'React JS Developer', 'React JS Developer', 'React JS Developer',
#        'React JS Developer', 'React JS Developer', 'React JS Developer',
#        'React JS Developer', 'SQL Developer Lightning insight',
#        'SQL Developer Lightning insight',
#        'SQL Developer Lightning insight',
#        'SQL Developer Lightning insight',
#        'SQL Developer Lightning insight',
#        'SQL Developer Lightning insight',
# ...

# %%
XT = tfidf_vector.fit_transform(X)
model_knn = KNeighborsClassifier(n_neighbors=3)
Model_fit = model_RF.fit(XT,YT)

# %%
y_pred = Model_fit.predict(XT)

# %%
accuracy = accuracy_score(YT, y_pred)
accuracy
# Out:
# 0.9615384615384616
